# %% [markdown]
# Faça a análise descritiva da série que está nesse link:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt
import statsmodels.api as sm
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Load the data
url = "https://raw.githubusercontent.com/padsInsper/202234-fa/main/material/lab01/serie_temporal.csv"
df = pd.read_csv(url)

# %%
def custom_date(month, day):
    mydate = dt.date(
        year=1,
        month=month,
        day=day
    )
    return mydate

vec_custom_date = np.vectorize(custom_date)

# %%
year = 2019
month = 10
day = 31

# %%
date = dt.strftime(
    
)

# %%
custom_date(1,1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7266/3587874894.py in <module>
# ----> 1 custom_date(1,1)
#
# /tmp/ipykernel_7266/589887335.py in custom_date(month, day)
#       1 def custom_date(month, day):
# ----> 2     mydate = dt.date(
#       3         year=1,
#       4         month=month,
#       5         day=day)
#
# TypeError: unbound method datetime.date() needs an argument

# %%
# Create custom columns
df["ds"] = df["ds"].astype("datetime64[ns]")
df["year"] = df["ds"].dt.year
df["month"] = df["ds"].dt.month
df["day"] = df["ds"].dt.day
df["yealy"] = vec_custom_date(df["month"], df["day"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7266/3857002838.py in <module>
#       4 df["month"] = df["ds"].dt.month
#       5 df["day"] = df["ds"].dt.day
# ----> 6 df["yealy"] = vec_custom_date(df["month"], df["day"])
#
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/lib/python3/dist-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2239             res = func()
#    2240         else:
# -> 2241             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2242
#    2243             # Convert args to object arrays first
#
# ...

# %%
# Plot y
df['y'].plot.line()
plt.ylabel('y')
plt.xlabel('Date')
plt.title('Série Temporal')
plt.show()

# %%
# Plot seasonal y
sns.lineplot(
    df,
    x
)
